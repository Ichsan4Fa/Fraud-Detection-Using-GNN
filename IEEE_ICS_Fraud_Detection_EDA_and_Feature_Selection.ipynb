# %% [markdown]
# # EDA and Feature Selection IEEE-ICS Fraud Detection

# %%
# This following process are referenced by this link: https://www.kaggle.com/cdeotte/eda-for-columns-v-and-id
import pandas as pd #data processing
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)

# %%
import kagglehub

kagglehub.login()
path = kagglehub.competition_download('ieee-fraud-detection')

print("Path to competition files:", path)

# %%
import os
for dirname,_, filenames in os.walk('/kaggle/input'):
  for filename in filenames:
    print(os.path.join(dirname, filename))

# %%
data_id_train = pd.read_csv(path +'/train_identity.csv')
data_trans_train = pd.read_csv(path +'/train_transaction.csv')
data_id_test = pd.read_csv(path + '/test_identity.csv')
data_trans_test = pd.read_csv(path + '/test_transaction.csv')
